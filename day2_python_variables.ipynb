# %% [markdown]
# # Variables

# %% [markdown]
# ##### variables matlab:- Ek box jisme value store karte h

# %%
# Day 2: Python Variables
# Basic Examples

# %%
x = 10
print(x)
# Out:
# 10

# %%
print("number of students in python class:",12)
# Out:
# number of students in python class: 12

# %%
print("number of students in ML class:",56)
# Out:
# number of students in ML class: 56

# %%
print("number of students in SQL class:",34)
# Out:
# number of students in SQL class: 34

# %%
print("Total number of students:",12+56+34)
# Out:
# Total number of students: 102

# %%
print("number of students in (Python +ML) class:",12+56)
# Out:
# number of students in (Python +ML) class: 68

# %%
print("number of students in (ML +SQL) class:",56+34)
# Out:
# number of students in (ML +SQL) class: 90

# %%
print("number of students in (Python + SQL) class:",12+34)
# Out:
# number of students in (Python + SQL) class: 46

# %%
Pythonclass=56

# %%
print("no. of students in python class:",Pythonclass)
# Out:
# no. of students in python class: 56

# %%
python_class = 20.3
ml_class = 7.8
sql_class = 45.9
print("No. of students in Python class:",python_class)
print("No. of students in ML class:",ml_class)
print("No. of students in SQL class:",sql_class)
print("No. of students in (Python+ML) class:",python_class+ml_class)
print("No. of students in (ML+SQL) class:",ml_class+sql_class)
print("No. of students in (Python+SQL) class:",python_class+sql_class)
# Out:
# No. of students in Python class: 20.3
# No. of students in ML class: 7.8
# No. of students in SQL class: 45.9
# No. of students in (Python+ML) class: 28.1
# No. of students in (ML+SQL) class: 53.699999999999996
# No. of students in (Python+SQL) class: 66.2

# %%
python_class = "67"
ml_class = "44"
sql_class = "49"
print("No of students in Python class:",python_class)
print("No of students in ML class:",ml_class)
print("No of students in SQL class:",sql_class)
print("No of students in (Python+ML+SQL) class:",python_class+ml_class+sql_class)
print("No of students in (ML+SQL) class:",ml_class+sql_class)
# Out:
# No of students in Python class: 67
# No of students in ML class: 44
# No of students in SQL class: 49
# No of students in (Python+ML+SQL) class: 674449
# No of students in (ML+SQL) class: 4449

# %%
python_class = True
ml_class = False
sql_class = False
print("No of students in Python class:",python_class)
print("No of students in ML class:",ml_class)
print("No of students in SQL class",sql_class)
print("No of students in(Python+ML) class",python_class+ml_class)
print("No of students in(ML+SQL) class",ml_class+sql_class)
print("No of studens in(Python+SQL) class",python_class+sql_class)
print("Total no of students in(Python+ML+SQL) class",python_class+ml_class+sql_class)
# Out:
# No of students in Python class: True
# No of students in ML class: False
# No of students in SQL class False
# No of students in(Python+ML) class 1
# No of students in(ML+SQL) class 0
# No of studens in(Python+SQL) class 1
# Total no of students in(Python+ML+SQL) class 1

# %%
python_class = "pass"
ml_class = "fail"
sql_class = "pass"
print("No of students in Python class:",python_class)
print("No of students in ML class:",ml_class)
print("No of students in SQL class:",sql_class)
print("No of students in(Python+ML+SQL) class:",python_class + ml_class + sql_class)
print("No of students in(Python+ML) class:",python_class + ml_class)
print("No of students in(ML+SQL) class:",ml_class+  sql_class)
# Out:
# No of students in Python class: pass
# No of students in ML class: fail
# No of students in SQL class: pass
# No of students in(Python+ML+SQL) class: passfailpass
# No of students in(Python+ML) class: passfail
# No of students in(ML+SQL) class: failpass
