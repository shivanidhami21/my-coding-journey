# %% [markdown]
# # Comment

# %%
# Hello

# %% [markdown]
# # Hello

# %% [markdown]
# # Heading 1

# %% [markdown]
# # Shivani

# %% [markdown]
# # Shivani

# %% [markdown]
# ## Shivani

# %% [markdown]
# ### Shivani

# %% [markdown]
# #### Shivani

# %% [markdown]
# ##### Shivani

# %% [markdown]
# ##### Shivani

# %% [markdown]
# # Hastag is used for Heading

# %% [markdown]
# # Markdown is for Headings

# %%
# shivani
## shivani
### shivani
#### shivani
##### shivani

# %% [markdown]
# *shivani*

# %% [markdown]
# *shivani*
# **shivani**
# ***shivani***
# ****shivani****

# %%
*comment
single* is for italic
double** is for bold
triple*** is for both bold+italic
# Out:
#   Cell In[19], line 2
#     single* is for italic
#             ^
# SyntaxError: invalid syntax

# %%
*shivani* = Italic
**shivani** = Bold
***shivani*** = Bold + Italic

# %% [markdown]
# # hello

# %% [markdown]
# ## hello

# %% [markdown]
# *hello*

# %% [markdown]
# **hello**

# %% [markdown]
# # My name
# ## Shivani
# ### Python class
# **data science**
# *data science*

# %% [markdown]
# # Escape Sequence

# %% [markdown]
# # \n = New Line

# %%
print("hello\n\nworld")
# Out:
# hello
#
# world

# %%
print("hello\nworld")
# Out:
# hello
# world

# %%
print("hello world\nhello world")
# Out:
# hello world
# hello world

# %%
print("hello world \n hello world")
# Out:
# hello world
#  hello world

# %%
print("data\nscience")
# Out:
# data
# science

# %%
print("hello\nmy self shivan\nI am 22\nstudent of\ndata science
# Out:
#   Cell In[16], line 1
#     print("hello\nmy self shivan\nI am 22\nstudent of\ndata science
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello\nmy self shivani\nI am twenty two\ndata science student")
# Out:
# hello
# my self shivani
# I am twenty two
# data science student

# %%
print("1\n2\n3\n4\n5")
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print("lets \n \n code \n \n hello \n \n world")
# Out:
# lets
#
#  code
#
#  hello
#
#  world

# %%
print("lets\n\ncode\n\nhello\n\nworld")
# Out:
# lets
#
# code
#
# hello
#
# world

# %% [markdown]
# # Tab space - \t

# %% [markdown]
# ### ye ek bada horizontal space deta h

# %%
print("hello\tworld")
# Out:
# hello	world

# %%
print("This\tcar\tis\ton\tSale")
# Out:
# This	car	is	on	Sale

# %%
print("hello\t\tworld")
# Out:
# hello		world

# %%
print("hello\t\t\tworld")
# Out:
# hello			world

# %%
print("hello\t\t\tworld")
# Out:
# hello			world

# %%
print("hello\n\tworld")
# Out:
# hello
# 	world

# %%
print("hello\t\nworld")
# Out:
# hello
# world

# %%
print("hello\nprint\tworld\nprint")
# Out:
# hello
# print	world
# print

# %%
print("A\tB")
# Out:
# A	B

# %%
print("A\nB")
# Out:
# A
# B

# %% [markdown]
# # Data types

# %% [markdown]
# ## 1-Integer

# %%
12,45,63,52 #integer
# Out:
# (12, 45, 63, 52)

# %% [markdown]
# # 2-Float

# %%
2.4,6.7,9.8 #float
# Out:
# (2.4, 6.7, 9.8)

# %% [markdown]
# # 3-String

# %%
"vijAI","vijai","45","43","21","4.5","6.7","5.34","!@#$%^&*(0()" #string
# Out:
# ('vijAI', 'vijai', '45', '43', '21', '4.5', '6.7', '5.34', '!@#$%^&*(0()')

# %% [markdown]
# # 4-Boolean

# %% [markdown]
# ### True #boolean false #boolean

# %%
True #boolean False #boolean
# Out:
# True

# %% [raw]
# True   #   bool

# %%
print(type("hello"))
print(type("45"))
print(type("4.5"))
print(type("True"))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
print(type("hello"))
print(type(34))
print(type(4.5))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
print(type("45"))
print(type(25))
print(type(False))
print(type(3.1))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %%
"12"+"12"
# Out:
# '1212'

# %%
12+12
# Out:
# 24

# %%
"hello" + "world"
# Out:
# 'helloworld'

# %%
100-91
# Out:
# 9

# %%
89+87
# Out:
# 176

# %%
"64"+"34"
# Out:
# '6434'

# %% [markdown]
# ### Understanding Boolean Data Types

# %% [markdown]
# True = 1
# False = 0

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
False + True
# Out:
# 1

# %%
True + False + True
# Out:
# 2

# %%
False + False
# Out:
# 0

# %%
True + True + False
# Out:
# 2

# %%
True - False
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
False * False
# Out:
# 0

# %%
False * True
# Out:
# 0

# %% [markdown]
# # String Concatenation

# %% [markdown]
# string + string

# %%
"56" + "4"
# Out:
# '564'

# %%
"hello" + "world"
# Out:
# 'helloworld'

# %%
"56" + "56"
# Out:
# '5656'

# %% [markdown]
# #String-Join
# #Number-Add

# %%
"10" + "5"
# Out:
# '105'

# %%
10+5
# Out:
# 15

# %% [markdown]
# # 5- None Data Types

# %%
x = None
print(x)
# Out:
# None

# %%
None
