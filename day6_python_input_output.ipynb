# %% [markdown]
# # Input & Output in python

# %% [markdown]
# In this notebook, we wil learn:
# - print()
# - input()
# - User Input
# - Type Conversion

# %% [markdown]
# ## 1. Output using print()

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## 2. Taking Input fom User

# %%
name = input("Enter your name:")
print("Hello", name)
# Out:
# Enter your name: Shivani
# Hello Shivani

# %% [markdown]
# ## 3. Input Always Returns String

# %%
age = input("Enter your age:")
print(type(age))
# Out:
# Enter your age: 21
# <class 'str'>

# %% [markdown]
# ## 4. Type Conversion

# %%
age = int(input("Enter your age:"))
print(type(age))
# Out:
# Enter your age: 21
# <class 'int'>

# %% [markdown]
# ## 5. Addition of Two Numbers

# %%
num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number:"))

print("Sum =",num1 + num2)
# Out:
# Enter first number: 5
# Enter second number: 10
# Sum = 15

# %% [markdown]
# # Mini Project

# %%
name = input("Enter your name:")
age = int(input("Enter your age:"))

print("My name is", name)
print("I am", age, "years old")
# Out:
# Enter your name: Shivani Dhami
# Enter your age: 21
# My name is Shivani Dhami
# I am 21 years old

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Today I learned:
# - print()
# - input()
# - User Input
# - Type Conversion
