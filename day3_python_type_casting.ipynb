# %% [markdown]
# # Type casting

# %%
x = 45
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
x = int(x)
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
y = 12
print(y)
print(type(y))
# Out:
# 12
# <class 'int'>

# %%
y = float(y)
print(y)
print(type(y))
# Out:
# 12.0
# <class 'float'>

# %%
a = "pynative"
print(a)
print(type(a))
# Out:
# pynative
# <class 'str'>

# %%
s = 21
print(s)
print(type(s))
# Out:
# 21
# <class 'int'>

# %%
s = float(s)
print(s)
print(type(s))
# Out:
# 21.0
# <class 'float'>

# %%
r = 10
print(r)
print(type(r))
# Out:
# 10
# <class 'int'>

# %%
r = float(r)
print(r)
print(type(r))
# Out:
# 10.0
# <class 'float'>

# %%
t = 8.7
print(t)
print(type(t))
# Out:
# 8.7
# <class 'float'>

# %%
t = int(t)
print(t)
print(type(t))
# Out:
# 8
# <class 'int'>

# %%
t = bool(t)
print(t)
print(type(t))
# Out:
# True
# <class 'bool'>

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(5))
# Out:
# True

# %%
a = str(a)
print(a)
print(type(a))
# Out:
# pynative
# <class 'str'>

# %%
int(5.9)
# Out:
# 5

# %%
float(6)
# Out:
# 6.0

# %%
str(45)
# Out:
# '45'

# %%
bool(0)
# Out:
# False

# %%
bool(10)
# Out:
# True

# %%
x = 45
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
x = float(x)
print(x)
print(type(x))
# Out:
# 45.0
# <class 'float'>

# %%
y = 6.7
print(y)
print(type(y))
# Out:
# 6.7
# <class 'float'>

# %%
y = int(y)
print(y)
print(type(y))
# Out:
# 6
# <class 'int'>

# %%
z = 0
print(z)
print(type(z))
# Out:
# 0
# <class 'int'>

# %%
z = bool(z)
print(z)
print(type(z))
# Out:
# False
# <class 'bool'>

# %%
a = 9
a = str(a)
print(type(a))
# Out:
# <class 'str'>

# %%
b = 7.8
b = int(b)
print(type(b))
# Out:
# <class 'int'>

# %%
c = 5
c = bool(c)
print(type(c))
# Out:
# <class 'bool'>

# %%
a = 9
a = str(a)

print(a)
print(type(a))
# Out:
# 9
# <class 'str'>

# %%
x = 0
x = bool(x)
print(type(x))
# Out:
# <class 'bool'>

# %%
x = 0
x = bool(x)
print(x)
# Out:
# False

# %%
# Practice

num = "25"
print(type(num))

num = int(num)
print(type(num))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ## Conclusion
# Learned:
# - int()
# - float()
# - str()
# - bool()
#
# Type casting helps convert one data type into another.
